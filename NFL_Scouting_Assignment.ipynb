# %% [markdown]
# <a href="https://colab.research.google.com/github/rainyvermont822-cmyk/MIS2800/blob/main/NFL_Scouting_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Step 1: Import SQLite & Connect to Database

# %%
import sqlite3

#connect to (or create) the database
conn = sqlite3.connect('NFL_Scouting.db')

#Create a cursor object to run SQL commands
cursor = conn.cursor()

print('Database connected successfully')
# Out:
# Database connected successfully

# %% [markdown]
# #Step 2: Create the Table

# %%
#Create scouting_stats table
cursor.execute("""
CREATE TABLE IF NOT EXISTS scouting_stats(
    team_name TEXT,
    city TEXT,
    WINS INTEGER,
    points_per_game REAL
)
""")

conn.commit()
print("Table created successfully")
# Out:
# Table created successfully

# %% [markdown]
# #Step 3: Insert Sample Data

# %%
# Insert sample NFL team data
cursor.execute("""
INSERT INTO scouting_stats (team_name, city, wins, points_per_game)
VALUES
    ('Chiefs', 'Kansas City', 11, 29.2),
    ('Bills', 'Buffalo', 10, 26.5),
    ('Cowboys', 'Dallas', 12, 27.8),
    ('Jets', 'New York', 7, 18.6)
  """)

conn.commit()
print("Data inserted successfully")
# Out:
# Data inserted successfully

# %% [markdown]
# #Step 4: Filter Teams Averaging More Than 24 Points per Game

# %%
cursor.execute("""
SELECT * FROM scouting_stats
WHERE points_per_game > 24
""")

results = cursor.fetchall()

print("Teams averaging more than 24 points per game:")
for row in results:
    print(row)
# Out:
# Teams averaging more than 24 points per game:
# ('Chiefs', 'Kansas City', 11, 29.2)
# ('Bills', 'Buffalo', 10, 26.5)
# ('Cowboys', 'Dallas', 12, 27.8)

# %% [markdown]
# #Step 5: Sort Teams by Wins (Descending)

# %%
cursor.execute("""
SELECT * from scouting_stats
order by wins desc
""")

results = cursor.fetchall()

print("Teams sorted by wins (highest to lowest):")
for row in results:
  print(row)
# Out:
# Teams sorted by wins (highest to lowest):
# ('Cowboys', 'Dallas', 12, 27.8)
# ('Chiefs', 'Kansas City', 11, 29.2)
# ('Bills', 'Buffalo', 10, 26.5)
# ('Jets', 'New York', 7, 18.6)

# %% [markdown]
# #Step 6: Combo Challenge

# %%
cursor.execute("""
select * from scouting_stats
where wins > 5
order by city ASC
""")

results = cursor.fetchall()

print("Teams with more than 5 wins, sorted by sity:")
for row in results:
  print(row)
# Out:
# Teams with more than 5 wins, sorted by sity:
# ('Bills', 'Buffalo', 10, 26.5)
# ('Cowboys', 'Dallas', 12, 27.8)
# ('Chiefs', 'Kansas City', 11, 29.2)
# ('Jets', 'New York', 7, 18.6)

# %% [markdown]
# #Step 7: Save and Submit

# %%
conn.close()
print("Database connection closed")
# Out:
# Database connection closed
