# %% [markdown]
# <a href="https://colab.research.google.com/github/rainyvermont822-cmyk/MIS2800/blob/main/HelloWorld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello World")
# Out:
# hello World
