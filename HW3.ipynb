# %% [markdown]
# <a href="https://colab.research.google.com/github/rainyvermont822-cmyk/MIS2800/blob/main/HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for SQLite3 to work using SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# --Block 1
# Create Table Marketing_Brands (
#   brand_id Integer Primary key,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget TEXT
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', '7000000'),
#  (2, 'AWS', 'Technology', '15000000'),
#  (3, 'Pepsi', 'Beverages', '2000000'),
#  (4, 'He_Gets_Us', 'Religious', '1000000'),
#  (5, 'Dr_Pepper', 'Beverages', '5000000'),
#  (6, 'IBM', 'Technology', '100000'),
#  (7, 'Google', 'Technology', '8000000')]

# %%
# %%sql
# SELECT brand_type
# FROM Marketing_Brands
# WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Snacks',), ('Technology',)]

# %%
# %%sql
# -- Instructions: Fix the code to find the brand types that are Religious
# SELECT brand_type
# FROM Marketing_Brands
# WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Religious',)]

# %%
# %%sql
# SELECT brand_name
# FROM Marketing_Brands
# WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
# %%sql
# SELECT *
# FROM Marketing_Brands
# WHERE brand_budget > 7000000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(7, 'Google', 'Technology', '8000000')]

# %%
# %%sql
# --Instructions: Find the brands where the brand type is Snacks or Beverages.  Display only the brand names.
# SELECT brand_name
# FROM Marketing_Brands
# WHERE brand_type IN ('Snacks', 'Beverages');
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# -- Instructions: Sort the table by brand budget in DESC order. Display only the brand_name and brand_budget.
# SELECT brand_name, brand_budget
# FROM Marketing_Brands
# ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Google', '8000000'),
#  ('Doritos', '7000000'),
#  ('Dr_Pepper', '5000000'),
#  ('Pepsi', '2000000'),
#  ('AWS', '15000000'),
#  ('He_Gets_Us', '1000000'),
#  ('IBM', '100000')]

# %%
# %%sql
# SELECT *
# FROM Marketing_Brands
# ORDER BY brand_budget ASC
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', '100000'),
#  (4, 'He_Gets_Us', 'Religious', '1000000'),
#  (2, 'AWS', 'Technology', '15000000'),
#  (3, 'Pepsi', 'Beverages', '2000000'),
#  (5, 'Dr_Pepper', 'Beverages', '5000000'),
#  (1, 'Doritos', 'Snacks', '7000000'),
#  (7, 'Google', 'Technology', '8000000')]

# %% [markdown]
# #1.
# We are trying to Create a table and instead of just "CREATE", we need to type "CREATE TABLE". Another error is that 'brand_budget' needs TEXT after it and not integer because it is another column.

# %% [markdown]
# #2.
# When inserting values into a table, we need to tell it which table to insert into. So INSERT INTO 'table name'.

# %% [markdown]
# #3.
# A hastag is for comments in python, not commands. If we want to select all the columns, we need to tell it to select * and it will give us the columns.

# %% [markdown]
# #4.
# In order to list the rows that have a value of over 700000, you have to select the column 'brand_type' from the table and then give it the command to only list the ones that are over 700000.

# %% [markdown]
# #5.
# Another that is missing text. In order to pick the brand type that is religious, we need to select the brand type from the table and tell it we only want the one that is religious.

# %% [markdown]
# #6.
# Same thing with the missing text like the last two blocks

# %% [markdown]
# #7.
# In order to run SQLite, you need to start the code with "%%sql"

# %% [markdown]
# #8.
# You have to select the brand_name column first, then you have to do WHERE IN to show only the brands that are snacks and beverages.

# %% [markdown]
# #9.
# If you just want the brand name and brand budget, you have to list those and not an * where it shows you all of the columns. Also, you have to select it FROM the table and to sort it you use ORDER BY and type DESC after.

# %% [markdown]
# #10.
# You have to put "%%sql". Then you select all of the columns "*" from the table, and then order them by brand_budget by ASC for ascending.
